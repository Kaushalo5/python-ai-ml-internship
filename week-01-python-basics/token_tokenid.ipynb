# %%
text = "Who is the PM of India?"

# %%
import tiktoken

# %%
tokenizer = tiktoken.encoding_for_model("gpt-4")

# %%
tokensID = tokenizer.encode(text)
tokensID
# Out:
# [15546, 374, 279, 5975, 315, 6890, 30]

# %%
result = [791, 5975, 315, 6890, 374, 67432, 35489,]
tokens = tokenizer.decode(result)
tokens
# Out:
# 'The PM of India is Narendra Modi'
