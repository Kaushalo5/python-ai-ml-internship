# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix

# %%
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

mse, r2
# Out:
# c:\Users\Kaushal\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_regression.py:1288: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# (7.888609052210118e-31, nan)

# %%
X = np.array([[20], [25], [30], [35], [40]])
y = np.array([0, 0, 1, 1, 1])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
log_model = LogisticRegression()
log_model.fit(X_train, y_train)

y_pred = log_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

accuracy, conf_matrix
# Out:
# c:\Users\Kaushal\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:620: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# (1.0, array([[1]]))

# %% [markdown]
# ## Machine Learning Fundamentals – Week 4
#
# ### Linear Regression
# - Predicts continuous values
# - Metrics: MSE, R² Score
#
# ### Logistic Regression
# - Used for classification
# - Metrics: Accuracy, Confusion Matrix
#
# ### Conclusion
# Both regression models were implemented and evaluated successfully.
